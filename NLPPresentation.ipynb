# %%
# !pip install openai
import os
import openai

#openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_key="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"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 469 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 163 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 42 kB 1.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for openai: filename=openai-0.20.0-py3-none-any.whl size=54118 sha256=0c73c08ae39666bd112151f1bd52009d9c3229e49b37f84600b7c30914140eaf
#   Stored in directory: /root/.cache/pip/wheels/71/8d/9b/e28529ec53123e0279208f99148d4661232120d78cb866839b
# ...

# %%
response = openai.Completion.create(
  model="text-davinci-002",
  prompt="Write an essay about Natural Language Processing",
  temperature=0.5,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)
print(response.choices[0].text)
# Out:
# Natural language processing (NLP) is a field of computer science, artificial intelligence, and linguistics concerned with the interactions between computers and human (natural) languages. As such, NLP is related to the area of human-computer interaction. Many challenges in NLP involve natural language understanding, that is, enabling computers to derive meaning from human or natural language input, and others involve natural language generation.
#
# NLP research has been applied to a wide range of tasks, including machine translation, information retrieval, question answering, text summarization, sentiment analysis, dialogue systems, and speech recognition. The research community is also focusing on developing deeper models of language that can support more nuanced applications such as machine reading, where a computer reads and

# %%
response = openai.Completion.create(
  model="text-davinci-002",
  prompt="Tell the architecture of GPT3",
  temperature=0.5,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nGPT3 is a neural network-based natural language processing model. It is designed to predict the next word in a sentence, based on the previous words in the sentence."
#     }
#   ],
#   "created": 1659887860,
#   "id": "cmpl-5ccwmpNQS0pAfJchiZuokg6e8W3Zx",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 37,
#     "prompt_tokens": 7,
#     "total_tokens": 44
#   }
# }

# %%
response = openai.Completion.create(
  model="text-davinci-002",
  prompt="What are different wordtovec representations",
  temperature=0.5,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "?\n\nThere are many different ways to represent words as vectors. Some common methods are one-hot encoding, bag-of-words, and word2vec."
#     }
#   ],
#   "created": 1659093602,
#   "id": "cmpl-5ZIKAgStg3XOoFyOiSi5b4BvxQeti",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 34,
#     "prompt_tokens": 8,
#     "total_tokens": 42
#   }
# }

# %%
response = openai.Completion.create(
  model="text-davinci-002",
  prompt="100 words story: Rewriting my family ever after",
  temperature=0.5,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nThe day started like any other day. I woke up, got dressed and went downstairs for breakfast. But something was different. Instead of my usual bowl of cereal, there was a note on the table.\n\n\"Dear Lily,\n\nI'm sorry to say that I'm not your real mother. Your real mother is someone else. I'm sorry for lying to you all these years, but I couldn't bear to tell you the truth.\n\nI hope you can forgive me.\n\nLove,\n\nMom\"\n\nI was in shock. I didn't know what to believe. Was this some kind of sick joke? But then I thought about all the times I'd felt like I didn't quite fit"
#     }
#   ],
#   "created": 1659093903,
#   "id": "cmpl-5ZIP1aqnyrDmaTX2jvQKEdNqk10KK",
#   "model": "text-davinci-002",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 150,
#     "prompt_tokens": 11,
#     "total_tokens": 161
#   }
# }
